# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
print(tf.__version__)
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
# Out:
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# 1.9.0
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import pandas as pd
"""
Cement (component 1)(kg in a m^3 mixture)	
Blast Furnace Slag (component 2)(kg in a m^3 mixture)	
Fly Ash (component 3)(kg in a m^3 mixture)	
Water  (component 4)(kg in a m^3 mixture)	
Superplasticizer (component 5)(kg in a m^3 mixture)	
Coarse Aggregate  (component 6)(kg in a m^3 mixture)	
Fine Aggregate (component 7)(kg in a m^3 mixture)	
Age (day)
Concrete compressive strength(MPa, megapascals) 
"""
csv_path = "/Users/lidakuang/workspace/cs584-s18-lida-kuang/Final Project/data/Concrete_Data.csv"
column_names = ['CEM', 'BLA','ASH', 'WAT', 'PLA', 'CAGG', 'FAGG', 'AGE', 'STRENTH']
concreate_strength = pd.read_csv(csv_path, skiprows=1, names=column_names)
#df = pd.DataFrame(concreate_strength, columns= column_names)
concreate_strength
# Out:
#         CEM    BLA    ASH    WAT   PLA    CAGG   FAGG  AGE  STRENTH
# 0     540.0    0.0    0.0  162.0   2.5  1040.0  676.0   28    79.99
# 1     540.0    0.0    0.0  162.0   2.5  1055.0  676.0   28    61.89
# 2     332.5  142.5    0.0  228.0   0.0   932.0  594.0  270    40.27
# 3     332.5  142.5    0.0  228.0   0.0   932.0  594.0  365    41.05
# 4     198.6  132.4    0.0  192.0   0.0   978.4  825.5  360    44.30
# 5     266.0  114.0    0.0  228.0   0.0   932.0  670.0   90    47.03
# 6     380.0   95.0    0.0  228.0   0.0   932.0  594.0  365    43.70
# 7     380.0   95.0    0.0  228.0   0.0   932.0  594.0   28    36.45
# 8     266.0  114.0    0.0  228.0   0.0   932.0  670.0   28    45.85
# 9     475.0    0.0    0.0  228.0   0.0   932.0  594.0   28    39.29
# 10    198.6  132.4    0.0  192.0   0.0   978.4  825.5   90    38.07
# 11    198.6  132.4    0.0  192.0   0.0   978.4  825.5   28    28.02
# 12    427.5   47.5    0.0  228.0   0.0   932.0  594.0  270    43.01
# ...

# %%
from sklearn.utils import shuffle
# Shuffle the date set
concreate_strength = shuffle(concreate_strength)
# Out:
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
datax = concreate_strength.iloc[:,0:(len(concreate_strength.columns)-1)]
datay = concreate_strength.iloc[:,(len(concreate_strength.columns)-1):len(concreate_strength.columns)]
datax[0:5]
# Out:
#        CEM    BLA    ASH    WAT   PLA    CAGG   FAGG  AGE
# 324  252.3    0.0   98.8  146.3  14.2   987.8  889.0    3
# 71   313.3  262.2    0.0  175.5   8.6  1046.9  611.8    3
# 925  164.0  163.0  128.0  197.0   8.0   961.0  641.0   28
# 438  167.0   75.4  167.0  164.0   7.9  1007.3  770.1   28
# 779  295.0    0.0    0.0  185.0   0.0  1069.0  769.0   28

# %%
datax.boxplot(figsize=(11,9))

# %%
#normalization to x
mean = datax.mean(axis=0)
std = datax.std(axis=0)
datax = (datax - mean) / std
datax[0:5]
# Out:
#           CEM       BLA       ASH       WAT       PLA      CAGG      FAGG  \
# 324 -0.276231 -0.856472  0.697090 -1.651537  1.338392  0.191387  1.439577
# 71   0.307466  2.182494 -0.846733 -0.284126  0.400971  0.951477 -2.017817
# 925 -1.121155  1.032741  1.153361  0.722701  0.300534 -0.153290 -1.653619
# 438 -1.092449  0.017434  1.762765 -0.822661  0.283794  0.442178 -0.043411
# 779  0.132357 -0.856472 -0.846733  0.160751 -1.038638  1.235707 -0.057130
#
#           AGE
# 324 -0.675355
# 71  -0.675355
# 925 -0.279597
# 438 -0.279597
# 779 -0.279597

# %%
#Check correlation
# plot the heatmap
sns.set(style="white")
cmap = sns.diverging_palette(220, 10, as_cmap=True)
corr = datax.corr()
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            cmap=cmap,
            annot=True,
            vmax=.5, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
datax.boxplot(figsize=(11,9))

# %%
datay[0:5]
# Out:
#      STRENTH
# 324    21.78
# 71     28.80
# 925    27.23
# 438    41.41
# 779    25.18

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

trainx, testx, trainy, testy = train_test_split(datax, datay, test_size=0.2)
# Out:
# /Users/lidakuang/anaconda2/envs/cs584/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def plot_history(history):
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [1000s]')
    plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']), 
               label='Val loss')
    plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
               label = 'Train Loss')
    plt.legend()
    plt.ylim([0,5])
        
# Display training progress by printing a single dot for each completed epoch.
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs):
        if epoch % 100 == 0: print('')
        print('.', end='')
    
def r2_score(y, y_hat):
    tot = np.sum((y-np.mean(y))**2)
    pre = np.sum((y-y_hat)**2)
    
    return(1 - pre/tot)

def MSE(y,y_hat):
    return (np.sum((y-y_hat)**2))/len(y)

# %%
def build_model(train_data):
    model = keras.Sequential([
    keras.layers.Dense(256, activation=tf.nn.relu, 
                        input_shape=(train_data.shape[1],)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(8, activation=tf.nn.relu),
    keras.layers.Dense(1)
    ])
        
    optimizer = tf.train.RMSPropOptimizer(0.001)

    model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae'])
    return model

model = build_model(trainx)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 256)               2304
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# ...
# Total params: 43,985
# Trainable params: 43,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
# The patience parameter is the amount of epochs to check for improvement.
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=100)

EPOCHS = 500

# Store training stats
history = model.fit(trainx.copy(), trainy.copy(), epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# ....................................................................................................
# ....................................................................................................
# .........................

# %%
y_hat = model.predict(testx).flatten()

r2 = r2_score(testy.values[:,0], y_hat)
mse = MSE(testy.values[:,0], y_hat)
print("R2 score: %7.5f" % r2)
print("MSE: %7.5f" % mse)
# Out:
# R2 score: 0.87683
# MSE: 34.66654

# %%
[loss, mae] = model.evaluate(testx, testy, verbose=0)

print("Testing set Mean Abs Error: {:7.2f}".format(mae))
# Out:
# Testing set Mean Abs Error:    4.30

# %%
#Change to one layer model
def build_model_1L(train_data):
    
    model = keras.Sequential([
            keras.layers.Dense(256, activation=tf.nn.relu, 
                           input_shape=(train_data.shape[1],)),
#         keras.layers.Dense(128, activation=tf.nn.relu),
#         keras.layers.Dense(64, activation=tf.nn.relu),
#         keras.layers.Dense(8, activation=tf.nn.relu),
        keras.layers.Dense(1)
      ])
        
    optimizer = tf.train.RMSPropOptimizer(0.001)

    model.compile(loss='mse',
                    optimizer=optimizer,
                    metrics=['mae'])
    return model

model_1L = build_model_1L(trainx)
model_1L.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 256)               2304
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 257
# ...
# Total params: 2,561
# Trainable params: 2,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_1L = model_1L.fit(trainx.copy(), trainy.copy(), epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history_1L)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
y_hat_1L = model_1L.predict(testx).flatten()

r2_1L = r2_score(testy.values[:,0], y_hat_1L)
mse_1L = MSE(testy.values[:,0], y_hat_1L)

print("R2 score: %7.5f" % r2_1L)
print("MSE: %7.5f" % mse_1L)
# Out:
# R2 score: 0.87215
# MSE: 35.98550

# %%
def build_model_2L(train_data):
    
    model = keras.Sequential([
        keras.layers.Dense(256, activation=tf.nn.relu, 
                           input_shape=(train_data.shape[1],)),
#         keras.layers.Dense(128, activation=tf.nn.relu),
        keras.layers.Dense(64, activation=tf.nn.relu),
#         keras.layers.Dense(8, activation=tf.nn.relu),
        keras.layers.Dense(1)
      ])
        
    optimizer = tf.train.RMSPropOptimizer(0.001)

    model.compile(loss='mse',
                    optimizer=optimizer,
                    metrics=['mae'])
    return model

model_2L = build_model_2L(trainx)
model_2L.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 256)               2304
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# ...
# Total params: 18,817
# Trainable params: 18,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_2L = model_2L.fit(trainx.copy(), trainy.copy(), epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history_2L)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# .......................................................................

# %%
y_hat_2L = model_2L.predict(testx).flatten()

r2_2L = r2_score(testy.values[:,0], y_hat_2L)
mse_2L = MSE(testy.values[:,0], y_hat_2L)

print("R2 score: %7.5f" % r2_2L)
print("MSE: %7.5f" % mse_2L)
# Out:
# R2 score: 0.90125
# MSE: 27.79377

# %%
def build_model_LN(train_data):
    
    model = keras.Sequential([
        keras.layers.Dense(30, activation=tf.nn.relu, 
                           input_shape=(train_data.shape[1],)),
        keras.layers.Dense(10, activation=tf.nn.relu),
        keras.layers.Dense(1, activation=tf.nn.relu),
        keras.layers.Dense(10, activation=tf.nn.relu),
        keras.layers.Dense(1)
      ])
        
    optimizer = tf.train.RMSPropOptimizer(0.001)

    model.compile(loss='mse',
                    optimizer=optimizer,
                    metrics=['mae'])
    return model

model_LN = build_model_LN(trainx)
model_LN.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_20 (Dense)             (None, 30)                270
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                310
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 11
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 11
# ...
# Total params: 622
# Trainable params: 622
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_LN = model_LN.fit(trainx.copy(), trainy.copy(), epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[early_stop, PrintDot()])

plot_history(history_LN)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
y_hat_LN = model_LN.predict(testx).flatten()

r2_LN = r2_score(testy.values[:,0], y_hat_LN)
mse_LN = MSE(testy.values[:,0], y_hat_LN)

print("R2 score: %7.5f" % r2_LN)
print("MSE: %7.5f" % mse_LN)
# Out:
# R2 score: 0.87761
# MSE: 34.44820
